# %%
import sys
import json
import csv
import yaml

import importlib

import pandas as pd
import numpy as np
import math

import matplotlib as mpl
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

from datetime import time
from datetime import date
from datetime import datetime
# with the above choices, the imported datetime.time(2023,07,01) is recognized
# from datetime import date
# from datetime import datetime

import pprint

import psycopg2
from sqlalchemy import create_engine, text as sql_text

# Create an utilities file util.py in a folder benchmarking and import it
sys.path.append('helper_functions/')
# import util as util
import util

# %%
from pymongo import MongoClient

client = MongoClient()

# %%
# I have (or will have) a database "airbnb"
db = client.airbnb


print('The list of all databases currently in the MongoDB client is:')
print(client.list_database_names())

print('\nThe list of all collections in the airbnb database is:')
print(db.list_collection_names())
# Note: calendar may not show up yet; it is created only when a first document is inserted into it
# Out:
# The list of all databases currently in the MongoDB client is:
# ['admin', 'airbnb', 'config', 'local', 'test']
#
# The list of all collections in the airbnb database is:
# ['listings_with_calendar', 'listings', 'reviews', 'listings_with_reviews_m', 'calendar', 'listings_test']

# %% [markdown]
# ### Building **listings_with_reviews_and_cal**

# %%
db.listings_with_reviews_and_cal.drop()

pipeline = [
    {
        '$lookup':
        {
            'from': 'listings_with_calendar',
            'localField': 'id',
            'foreignField': '_id',
            'as': 'cal_docs'
        }
    },
    {
        '$unwind':
        {
            'path': '$cal_docs',
            'preserveNullAndEmptyArrays': True
        }
    },
    {
        '$addFields':{
            'average_price': '$$ROOT.cal_docs.average_price',
            'first_available_date': '$$ROOT.cal_docs.first_available_date',
            'last_available_date': '$$ROOT.cal_docs.last_available_date',
            'dates_list': '$$ROOT.cal_docs.dates_list'

        }
    },
    {
        '$unset': 'cal_docs'
    },
    {
        '$out': 'listings_with_reviews_and_cal'
    }
]

time1 = datetime.now()
test1 = db.listings_with_reviews_m.aggregate(pipeline)
time2 = datetime.now()
diff = util.time_diff(time1, time2)

print('\nTime it took was:', format(diff, '.4f'), '.')

print(db.list_collection_names())
# Out:
# Time it took was: 15.9775 .
# ['listings_with_reviews_and_cal', 'listings_with_calendar', 'listings', 'reviews', 'listings_with_reviews_m', 'calendar', 'listings_test']

# %%
print(db.listings_with_reviews_and_cal.count_documents({}))

cursor = db.listings_with_reviews_and_cal.find({'id' : {'$regex' : '^1000.*$'}})
    
l = list(cursor)
print(len(l))
# Out:
# 39202
# 43

# %%
db.listings_with_reviews_and_cal.find_one()
# Out:
# {'_id': ObjectId('665ea170e9a75767d0524773'),
#  'id': '977395984065981849',
#  'name': 'Home in Brooklyn · 1 bedroom · 1 bed · 1 bath',
#  'host_id': '95344065',
#  'host_name': 'Derek',
#  'neighbourhood_group': 'Brooklyn',
#  'neighbourhood': 'Sheepshead Bay',
#  'latitude': 40.59179,
#  'longitude': -73.94285,
#  'room_type': 'Private room',
#  'price': 30.0,
#  'minimum_nights': 31,
#  'number_of_reviews': 1,
#  'last_review': datetime.datetime(2024, 1, 3, 0, 0),
#  'reviews_per_month': 0.86,
#  'calculated_host_listings_count': 7,
#  'availability_365': 339,
#  'number_of_reviews_ltm': 1,
#  'license': nan,
#  'reviews': [{'listing_id': '977395984065981849',
#    'id': '1060927930986644037',
#    'date': datetime.datetime(2024, 1, 3, 0, 0),
#    'reviewer_id': '56179331',
#    'reviewer_name': 'Sean',
#    'comments': 'I fear it’s kind of a “you get what you pay for” situation. The place is very dirty, especially the common rooms where the cupboards are caked and grease and stickiness. To the point that even opening a drawer or grabbing a handle requires washing your hands after. The bathroom has moldy rugs and had cockroaches. There’s occasionally a smell. The internet is very hit or miss and the temperature fluxuates a lot in the apartment.<br/>To their credit though, the bedrooms are clean enough and pretty comfortable. The floors a bit dusty but I kinda just dusted that up. The neighborhood itself is nice if you’re looking for something that feels quieter than the rest of the city. I enjoyed having plenty of stores, restaurants, and even a movie theater in walking distance while still being on a quiet residential street. That said, for commuting it does take about an hour to get to Manhattan.<br/>Like I said, it is extremelly cheap but that means it’s not well-maintained; so you get what you pay for.'}],
#  'average_price': 30.0,
#  'first_available_date': datetime.datetime(2024, 2, 6, 0, 0),
#  'last_available_date': datetime.datetime(2025, 2, 4, 0, 0),
#  'dates_list': [{'date': datetime.datetime(2024, 2, 6, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 7, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 8, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 9, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 10, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 11, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 12, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 13, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 14, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 15, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 16, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 17, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 18, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 19, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 20, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 21, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 22, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 23, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 24, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 25, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 26, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 27, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 28, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 2, 29, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 1, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 2, 0, 0),
#    'available': False,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 3, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 4, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 5, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 6, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 7, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 8, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 9, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 10, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 11, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 12, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 13, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 14, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 15, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 16, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 17, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 18, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 19, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 20, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 21, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 22, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 23, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 24, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 25, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 26, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 27, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 28, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 29, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 30, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 3, 31, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 1, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 2, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 3, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 4, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 5, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 6, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 7, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 8, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 9, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 10, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 11, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 12, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 13, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 14, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 15, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 16, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 17, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 18, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 19, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 20, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 21, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 22, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 23, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 24, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 25, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 26, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 27, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 28, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 29, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 4, 30, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 1, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 2, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 3, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 4, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 5, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 6, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 7, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 8, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 9, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 10, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 11, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 12, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 13, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 14, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 15, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 16, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 17, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 18, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 19, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 20, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 21, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 22, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 23, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 24, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 25, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 26, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 27, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 28, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 29, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 30, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 5, 31, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 1, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 2, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 3, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 4, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 5, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 6, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 7, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 8, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 9, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 10, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 11, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 12, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 13, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 14, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 15, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 16, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 17, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 18, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 19, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 20, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 21, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 22, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 23, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 24, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 25, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 26, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 27, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 28, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 29, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 6, 30, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 1, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 2, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 3, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 4, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 5, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 6, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 7, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 8, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 9, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 10, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 11, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 12, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 13, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 14, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 15, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 16, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 17, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 18, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 19, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 20, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 21, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 22, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 23, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 24, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 25, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 26, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 27, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 28, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 29, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 30, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 7, 31, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 1, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 2, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 3, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 4, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 5, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 6, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 7, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 8, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 9, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 10, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 11, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 12, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 13, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 14, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 15, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 16, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 17, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 18, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 19, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 20, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 21, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 22, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 23, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 24, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 25, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 26, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 27, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 28, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 29, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 30, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 8, 31, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 1, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 2, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 3, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 4, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 5, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 6, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 7, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 8, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 9, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 10, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 11, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 12, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 13, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 14, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 15, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 16, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 17, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 18, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 19, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 20, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 21, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 22, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 23, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 24, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 25, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 26, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 27, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 28, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 29, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 9, 30, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 1, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 2, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 3, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 4, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 5, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 6, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 7, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 8, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 9, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 10, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 11, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 12, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 13, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 14, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 15, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 16, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 17, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 18, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 19, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 20, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 21, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 22, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 23, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 24, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 25, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 26, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 27, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 28, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 29, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 30, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 10, 31, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 1, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 2, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 3, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 4, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 5, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 6, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 7, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 8, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 9, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 10, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 11, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 12, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 13, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 14, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 15, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 16, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 17, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 18, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 19, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 20, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 21, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 22, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 23, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 24, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 25, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 26, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 27, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 28, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 29, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 11, 30, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 1, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 2, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 3, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 4, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 5, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 6, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 7, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 8, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 9, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 10, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 11, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 12, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 13, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 14, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 15, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 16, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 17, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 18, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 19, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 20, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 21, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 22, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 23, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 24, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 25, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 26, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 27, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 28, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 29, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 30, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2024, 12, 31, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 1, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 2, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 3, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 4, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 5, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 6, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 7, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 8, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 9, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 10, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 11, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 12, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 13, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 14, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 15, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 16, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 17, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 18, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 19, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 20, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 21, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 22, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 23, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 24, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 25, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 26, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 27, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 28, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 29, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 30, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 1, 31, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 2, 1, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 2, 2, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 2, 3, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365},
#   {'date': datetime.datetime(2025, 2, 4, 0, 0),
#    'available': True,
#    'price': 30.0,
#    'minimum_nights': 31,
#    'maximum_nights': 365}]}

# %%
def isnan(val):
    return val != val

# %%
def convert_lwrac_to_json(doc):
    doc_new = {}

    doc_new['_id'] = str(doc['_id'])

    for key in ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews']:
        if not isnan(doc[key]):
            doc_new[key] = doc[key]
        else:
            doc_new[key] = None

    if doc['last_review']:
        doc_new['last_review'] = doc['last_review'].strftime('%Y-%m-%d')
    else:
        doc_new['last_review'] = None
    
    for key in ['reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'number_of_reviews_ltm']:
        if not isnan(doc[key]):
            doc_new[key] = doc[key]
        else:
            doc_new[key] = None

    if not isnan(doc['license']):
        doc_new['license'] = doc['license']
    else:
        doc_new['license'] = ""


    doc_new['average_price'] = doc['average_price']

    if doc['first_available_date']:
        doc_new['first_available_date'] = doc['first_available_date'].strftime('%Y-%m-%d')
    else:
        doc_new['first_available_date'] = None

    if doc['last_available_date']:
        doc_new['last_available_date'] = doc['last_available_date'].strftime('%Y-%m-%d')
    else:
        doc_new['last_available_date'] = None
    
    dlist = []
    for d in doc['reviews']:
        d_new = {}
        for key in ['listing_id', 'id']:
            if not isnan(d[key]):
                d_new[key] = d[key]
            else:
                d_new[key] = None

        if d['date']:
            d_new['date'] = d['date'].strftime('%Y-%m-%d')
        else:
            d_new['date'] = None

        for key in ['reviewer_id', 'reviewer_name', 'comments']:
            if not isnan(d[key]):
                d_new[key] = d[key]
            else:
                d_new[key] = None

        dlist.append(d_new)

    doc_new['reviews'] = dlist

    date_list = []
    for date in doc['dates_list']:
        date_new = {}
        date_new['date'] = date['date'].strftime('%Y-%m-%d')
        for key in ['price', 'minimum_nights', 'maximum_nights']:
            if not isnan(date[key]):
                date_new[key] = date[key]
            else:
                date_new[key] = None
        date_new['available'] = date['available']
        date_list.append(date_new)
    
    doc_new['dates_list'] = date_list

    return doc_new

# %%
cursor = db.listings_with_reviews_and_cal.find({'id' : {'$regex' : '^1000.*$'}})

output = []

for doc in cursor:
    output.append(convert_lwrac_to_json(doc))

print(len(output))
# Out:
# 43

# %%
# Writing dict to a json file into a json file in a subdirectory
# Also putting this function into my util.py
def write_dict_to_dir_json(dict, dir, filename):
    with open(dir + '/' + filename, 'w') as fp:
        json.dump(dict, fp)

dir = 'OUTPUTS'
filename = 'listings_with_reviews_and_cal_subset_1000.json'
write_dict_to_dir_json(output, dir, filename)
